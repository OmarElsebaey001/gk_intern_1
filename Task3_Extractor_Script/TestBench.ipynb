# %%
from TableDataClass import TableData
import pandas as pd
import glob


main=[]
for pdf in glob.glob('./PDFS/*'):
    extractor=TableData(pdf)
    temp=extractor.extractData()
    temp['File']=pdf.replace('./PDFS/',"")
    main.append(temp)

df=pd.concat(main,ignore_index=True)  
df
# Out:
#             Order No. OrderTime  TradeNo. TradeTime            Company Name  \
# 0    1000000014637162  13:26:59  05370942  15:15:54   APOLLO PIPES LIMITED.
# 1    1000000014637162  13:26:59  05603752  15:25:37   APOLLO PIPES LIMITED.
# 2    1000000014637162  13:26:59  05630863  15:27:03   APOLLO PIPES LIMITED.
# 3    1000000014651093  13:27:21  03983623  13:27:24  BHARTI AIRTEL LIMITED.
# 4    1000000014664400  13:27:43  03986037  13:27:43      CAN FIN HOMES LTD.
# ..                ...       ...       ...       ...                     ...
# 296  1100000015836542  13:37:29  29502165  13:37:29       DCB BANK LIMITED.
# 297  1100000015836542  13:37:29  29502166  13:37:29       DCB BANK LIMITED.
# 298  1100000015836542  13:37:29  29502167  13:37:29       DCB BANK LIMITED.
# 299  1100000015836542  13:37:29  29502168  13:37:29       DCB BANK LIMITED.
# 300  1100000015836542  13:37:29  29502169  13:37:29       DCB BANK LIMITED.
#
# ...
